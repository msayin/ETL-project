# %%
import numpy as np
import pandas as pd
import datetime as dt
import requests

# %%
# Import csv file, GDP by city, year
# the csv file is downloaded from https://stats.oecd.org/Index.aspx?DataSetCode=CITIES
GDP_file="Resources/CITIES_02022019170650160.csv"
GDP_df = pd.read_csv(GDP_file, encoding="ISO-8859-1")
GDP_df.head()
# Out:
#   METRO_ID Metropolitan areas           VAR  \
# 0   USA145         Nashville   GDP_REAL_PPP
# 1   USA145         Nashville   GDP_REAL_PPP
# 2   USA145         Nashville   GDP_REAL_PPP
# 3   USA145         Nashville   GDP_REAL_PPP
# 4   USA145         Nashville   GDP_REAL_PPP
#
#                                            Variables  TIME  Year Unit Code  \
# 0  GDP (Millions USD, constant prices, constant P...  2001  2001       USD
# 1  GDP (Millions USD, constant prices, constant P...  2002  2002       USD
# 2  GDP (Millions USD, constant prices, constant P...  2003  2003       USD
# 3  GDP (Millions USD, constant prices, constant P...  2004  2004       USD
# 4  GDP (Millions USD, constant prices, constant P...  2005  2005       USD
#
#         Unit  PowerCode Code PowerCode  Reference Period Code  \
# 0  US Dollar               0     Units                    NaN
# 1  US Dollar               0     Units                    NaN
# 2  US Dollar               0     Units                    NaN
# 3  US Dollar               0     Units                    NaN
# 4  US Dollar               0     Units                    NaN
#
#    Reference Period    Value  Flag Codes  Flags
# 0               NaN  12526.0         NaN    NaN
# 1               NaN  12970.0         NaN    NaN
# 2               NaN  13390.0         NaN    NaN
# 3               NaN  14022.0         NaN    NaN
# 4               NaN  14209.0         NaN    NaN

# %%
# filter in year=2015 and 2016
GDP_df=GDP_df.loc[GDP_df['Year'] >= 2015]
GDP_df.head()
# Out:
#    METRO_ID Metropolitan areas            VAR  \
# 14   USA145         Nashville    GDP_REAL_PPP
# 15   USA145         Nashville    GDP_REAL_PPP
# 30    UK560             Oxford  GDP_PC_SH_NAT
# 31    UK560             Oxford  GDP_PC_SH_NAT
# 46    UK569            Ipswich     GDP_SH_NAT
#
#                                             Variables  TIME  Year Unit Code  \
# 14  GDP (Millions USD, constant prices, constant P...  2015  2015       USD
# 15  GDP (Millions USD, constant prices, constant P...  2016  2016       USD
# 30  Share GDP per capita in Metropolitan area over...  2015  2015        PC
# 31  Share GDP per capita in Metropolitan area over...  2016  2016        PC
# 46  Share of GDP in Metropolitan area over the nat...  2015  2015        PC
#
#           Unit  PowerCode Code PowerCode  Reference Period Code  \
# 14   US Dollar               0     Units                    NaN
# 15   US Dollar               0     Units                    NaN
# 30  Percentage               0     Units                    NaN
# 31  Percentage               0     Units                    NaN
# 46  Percentage               0     Units                    NaN
#
#     Reference Period    Value  Flag Codes  Flags
# 14               NaN  19379.0         NaN    NaN
# 15               NaN  20452.0         NaN    NaN
# 30               NaN    123.7         NaN    NaN
# 31               NaN    123.4         NaN    NaN
# 46               NaN      0.5         NaN    NaN

# %%
# Create total GDP dataframe
Total_GDP_df=GDP_df.loc[GDP_df['Variables'] == "GDP (Millions USD, constant prices, constant PPP, base year 2010)"]
Total_GDP_df = Total_GDP_df[['METRO_ID', 'Metropolitan areas','Year','Value']].copy()
GDP_average = Total_GDP_df.groupby(['METRO_ID', 'Metropolitan areas']).mean()["Value"].rename("Total GDP")
Final_GDP_df = pd.DataFrame({"Total GDP(millions)": GDP_average})
Final_GDP_df.head()
# Out:
#                              Total GDP(millions)
# METRO_ID Metropolitan areas
# AT001    Vienna                         130700.0
# AT002    Graz                            19246.0
# AT003    Linz                            29148.0
# AT004    Salzburg                        19432.0
# AT005    Innsbruck                       14331.0

# %%
# Create GDP per capita dataframe
Percapita_GDP_df=GDP_df.loc[GDP_df['Variables'] == "GDP per capita (USD, constant prices, constant PPP, base year 2010)"]
Percapita_GDP_df = Percapita_GDP_df[['METRO_ID', 'Metropolitan areas','Year','Value']].copy()
GDP_average_2 = Percapita_GDP_df.groupby(['METRO_ID', 'Metropolitan areas']).mean()["Value"].rename("Percapita GDP")
Final_Percapita_GDP_df = pd.DataFrame({"Percapita GDP": GDP_average_2})
Final_Percapita_GDP_df.head()
# Out:
#                              Percapita GDP
# METRO_ID Metropolitan areas
# AT001    Vienna                    46787.0
# AT002    Graz                      45376.0
# AT003    Linz                      46498.0
# AT004    Salzburg                  55594.0
# AT005    Innsbruck                 46502.0

# %%
# Merge Total GDP and GDP per capita

merge_table = pd.merge(Final_GDP_df, Final_Percapita_GDP_df, on=['METRO_ID', 'Metropolitan areas'], how="inner")
merge_table.head()
# Out:
#                              Total GDP(millions)  Percapita GDP
# METRO_ID Metropolitan areas
# AT001    Vienna                         130700.0        46787.0
# AT002    Graz                            19246.0        45376.0
# AT003    Linz                            29148.0        46498.0
# AT004    Salzburg                        19432.0        55594.0
# AT005    Innsbruck                       14331.0        46502.0

# %%
# Export to csv
merge_table.to_csv("Output/GDP by city.csv", index=True, header=True)
